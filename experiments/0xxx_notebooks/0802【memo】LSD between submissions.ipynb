# %%
import gc
import io
import itertools
import multiprocessing as mp
from urllib.parse import urlparse

import numpy as np
import google.cloud.storage as gcs
import pandas as pd
import seaborn as sns
import Levenshtein
from retrying import retry
from tqdm.auto import tqdm

# %%
GCP_PROJECT = "dena-ai-training-28-gcp"
client = gcs.Client(project=GCP_PROJECT)
bucket = client.get_bucket("kfujikawa-kaggle-bms-molecular-generation")

submissions = [
    pd.read_csv(io.BytesIO(blob.download_as_string())).assign(
        filename=blob.name.split("/")[-1]
    ).sort_values("image_id").reset_index(drop=True)
    for blob in tqdm(list(bucket.list_blobs(prefix="submissions/", delimiter="/")))
    if blob.path.endswith(".csv")
]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=15.0), HTML(value='')))

# %%
def calc_levenshtein(ij):
    i, j = ij
    df1, df2 = submissions[i], submissions[j]
    return np.mean([
        Levenshtein.distance(x, y)
        for x, y in zip(df1.InChI, df2.InChI)
    ])


model_names = pd.concat(submissions, ignore_index=True).filename.unique()
lev_matrix = pd.DataFrame(columns=model_names, index=model_names)
for model_name in model_names:
    lev_matrix.loc[model_name, model_name] = 0

iterator = list(itertools.combinations(range(len(submissions)), 2))
mapfunc = map(calc_levenshtein, iterator)
for i, lev in enumerate(tqdm(mapfunc, total=len(iterator))):
    x, y = iterator[i]
    lev_matrix.loc[model_names[x], model_names[y]] = lev
    lev_matrix.loc[model_names[y], model_names[x]] = lev
lev_matrix
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=91.0), HTML(value='')))
#                                    CV073_LB074.csv  \
# CV073_LB074.csv                                  0
# Final_LB054weight_tuned.csv                0.43495
# LB054_LB054_2.5*camaro.csv                0.452226
# LB054_LB055+camaro_predictions.csv        0.426708
# LB055_LB056+camaro*1.5.csv                0.355714
# LB055_LB056+full_candidates.csv            0.40937
# LB056.csv                                 0.313811
# LB056_LB055+bugfixed.csv                  0.330938
# LB057_LB056+safe_candidates.csv           0.353224
# LB058_LB056+kyakaap*1.5.csv               0.288297
# LB058_exp084+full_kyakaap.csv             0.330546
# LB059+kf0527.csv                           0.32524
# LB063_camaro_only.csv                     0.438854
# LB085_LB063+camaro_predictions.csv        0.759658
#
#                                    Final_LB054weight_tuned.csv  \
# CV073_LB074.csv                                        0.43495
# Final_LB054weight_tuned.csv                                  0
# LB054_LB054_2.5*camaro.csv                           0.0377958
# LB054_LB055+camaro_predictions.csv                   0.0329353
# LB055_LB056+camaro*1.5.csv                             0.16327
# LB055_LB056+full_candidates.csv                      0.0630132
# LB056.csv                                             0.182641
# LB056_LB055+bugfixed.csv                               0.16414
# LB057_LB056+safe_candidates.csv                       0.153219
# LB058_LB056+kyakaap*1.5.csv                           0.209287
# LB058_exp084+full_kyakaap.csv                         0.212112
# LB059+kf0527.csv                                       0.22471
# LB063_camaro_only.csv                                 0.327837
# LB085_LB063+camaro_predictions.csv                    0.575847
#
#                                    LB054_LB054_2.5*camaro.csv  \
# CV073_LB074.csv                                      0.452226
# Final_LB054weight_tuned.csv                         0.0377958
# LB054_LB054_2.5*camaro.csv                                  0
# LB054_LB055+camaro_predictions.csv                  0.0422317
# LB055_LB056+camaro*1.5.csv                           0.178779
# LB055_LB056+full_candidates.csv                     0.0757512
# LB056.csv                                            0.203321
# LB056_LB055+bugfixed.csv                             0.182123
# LB057_LB056+safe_candidates.csv                      0.172074
# LB058_LB056+kyakaap*1.5.csv                          0.230668
# LB058_exp084+full_kyakaap.csv                        0.227263
# LB059+kf0527.csv                                     0.238209
# LB063_camaro_only.csv                                0.334067
# LB085_LB063+camaro_predictions.csv                   0.575525
#
#                                    LB054_LB055+camaro_predictions.csv  \
# CV073_LB074.csv                                              0.426708
# Final_LB054weight_tuned.csv                                 0.0329353
# LB054_LB054_2.5*camaro.csv                                  0.0422317
# LB054_LB055+camaro_predictions.csv                                  0
# LB055_LB056+camaro*1.5.csv                                   0.151987
# LB055_LB056+full_candidates.csv                              0.034197
# LB056.csv                                                    0.171949
# LB056_LB055+bugfixed.csv                                     0.151415
# LB057_LB056+safe_candidates.csv                              0.138566
# LB058_LB056+kyakaap*1.5.csv                                  0.199314
# LB058_exp084+full_kyakaap.csv                                0.209271
# LB059+kf0527.csv                                             0.221073
# LB063_camaro_only.csv                                        0.333284
# LB085_LB063+camaro_predictions.csv                           0.584937
#
#                                    LB055_LB056+camaro*1.5.csv  \
# CV073_LB074.csv                                      0.355714
# Final_LB054weight_tuned.csv                           0.16327
# LB054_LB054_2.5*camaro.csv                           0.178779
# LB054_LB055+camaro_predictions.csv                   0.151987
# LB055_LB056+camaro*1.5.csv                                  0
# LB055_LB056+full_candidates.csv                      0.152463
# LB056.csv                                           0.0712354
# LB056_LB055+bugfixed.csv                            0.0448355
# LB057_LB056+safe_candidates.csv                      0.118782
# LB058_LB056+kyakaap*1.5.csv                          0.102711
# LB058_exp084+full_kyakaap.csv                        0.117128
# LB059+kf0527.csv                                     0.130834
# LB063_camaro_only.csv                                0.259685
# LB085_LB063+camaro_predictions.csv                    0.50886
#
#                                    LB055_LB056+full_candidates.csv  LB056.csv  \
# CV073_LB074.csv                                            0.40937   0.313811
# Final_LB054weight_tuned.csv                              0.0630132   0.182641
# LB054_LB054_2.5*camaro.csv                               0.0757512   0.203321
# LB054_LB055+camaro_predictions.csv                        0.034197   0.171949
# LB055_LB056+camaro*1.5.csv                                0.152463  0.0712354
# LB055_LB056+full_candidates.csv                                  0   0.150093
# LB056.csv                                                 0.150093          0
# LB056_LB055+bugfixed.csv                                  0.128974  0.0299145
# LB057_LB056+safe_candidates.csv                           0.115351  0.0609564
# LB058_LB056+kyakaap*1.5.csv                               0.178115  0.0345936
# LB058_exp084+full_kyakaap.csv                             0.193719  0.0893159
# LB059+kf0527.csv                                          0.205014   0.101467
# LB063_camaro_only.csv                                     0.316056   0.248096
# LB085_LB063+camaro_predictions.csv                        0.596012   0.565287
#
#                                    LB056_LB055+bugfixed.csv  \
# CV073_LB074.csv                                    0.330938
# Final_LB054weight_tuned.csv                         0.16414
# LB054_LB054_2.5*camaro.csv                         0.182123
# LB054_LB055+camaro_predictions.csv                 0.151415
# LB055_LB056+camaro*1.5.csv                        0.0448355
# LB055_LB056+full_candidates.csv                    0.128974
# LB056.csv                                         0.0299145
# LB056_LB055+bugfixed.csv                                  0
# LB057_LB056+safe_candidates.csv                    0.085938
# LB058_LB056+kyakaap*1.5.csv                       0.0630565
# LB058_exp084+full_kyakaap.csv                     0.0911115
# LB059+kf0527.csv                                   0.103791
# LB063_camaro_only.csv                              0.234398
# LB085_LB063+camaro_predictions.csv                 0.552166
#
#                                    LB057_LB056+safe_candidates.csv  \
# CV073_LB074.csv                                           0.353224
# Final_LB054weight_tuned.csv                               0.153219
# LB054_LB054_2.5*camaro.csv                                0.172074
# LB054_LB055+camaro_predictions.csv                        0.138566
# LB055_LB056+camaro*1.5.csv                                0.118782
# LB055_LB056+full_candidates.csv                           0.115351
# LB056.csv                                                0.0609564
# LB056_LB055+bugfixed.csv                                  0.085938
# LB057_LB056+safe_candidates.csv                                  0
# LB058_LB056+kyakaap*1.5.csv                              0.0918213
# LB058_exp084+full_kyakaap.csv                             0.140059
# LB059+kf0527.csv                                          0.151656
# LB063_camaro_only.csv                                     0.289954
# LB085_LB063+camaro_predictions.csv                        0.593104
#
#                                    LB058_LB056+kyakaap*1.5.csv  \
# CV073_LB074.csv                                       0.288297
# Final_LB054weight_tuned.csv                           0.209287
# LB054_LB054_2.5*camaro.csv                            0.230668
# LB054_LB055+camaro_predictions.csv                    0.199314
# LB055_LB056+camaro*1.5.csv                            0.102711
# LB055_LB056+full_candidates.csv                       0.178115
# LB056.csv                                            0.0345936
# LB056_LB055+bugfixed.csv                             0.0630565
# LB057_LB056+safe_candidates.csv                      0.0918213
# LB058_LB056+kyakaap*1.5.csv                                  0
# LB058_exp084+full_kyakaap.csv                         0.101956
# LB059+kf0527.csv                                      0.111811
# LB063_camaro_only.csv                                 0.262062
# LB085_LB063+camaro_predictions.csv                    0.586799
#
#                                    LB058_exp084+full_kyakaap.csv  \
# CV073_LB074.csv                                         0.330546
# Final_LB054weight_tuned.csv                             0.212112
# LB054_LB054_2.5*camaro.csv                              0.227263
# LB054_LB055+camaro_predictions.csv                      0.209271
# LB055_LB056+camaro*1.5.csv                              0.117128
# LB055_LB056+full_candidates.csv                         0.193719
# LB056.csv                                              0.0893159
# LB056_LB055+bugfixed.csv                               0.0911115
# LB057_LB056+safe_candidates.csv                         0.140059
# LB058_LB056+kyakaap*1.5.csv                             0.101956
# LB058_exp084+full_kyakaap.csv                                  0
# LB059+kf0527.csv                                       0.0459784
# LB063_camaro_only.csv                                   0.204825
# LB085_LB063+camaro_predictions.csv                      0.528873
#
#                                    LB059+kf0527.csv LB063_camaro_only.csv  \
# CV073_LB074.csv                             0.32524              0.438854
# Final_LB054weight_tuned.csv                 0.22471              0.327837
# LB054_LB054_2.5*camaro.csv                 0.238209              0.334067
# LB054_LB055+camaro_predictions.csv         0.221073              0.333284
# LB055_LB056+camaro*1.5.csv                 0.130834              0.259685
# LB055_LB056+full_candidates.csv            0.205014              0.316056
# LB056.csv                                  0.101467              0.248096
# LB056_LB055+bugfixed.csv                   0.103791              0.234398
# LB057_LB056+safe_candidates.csv            0.151656              0.289954
# LB058_LB056+kyakaap*1.5.csv                0.111811              0.262062
# LB058_exp084+full_kyakaap.csv             0.0459784              0.204825
# LB059+kf0527.csv                                  0              0.207223
# LB063_camaro_only.csv                      0.207223                     0
# LB085_LB063+camaro_predictions.csv         0.533444              0.451753
#
#                                    LB085_LB063+camaro_predictions.csv
# CV073_LB074.csv                                              0.759658
# Final_LB054weight_tuned.csv                                  0.575847
# LB054_LB054_2.5*camaro.csv                                   0.575525
# LB054_LB055+camaro_predictions.csv                           0.584937
# LB055_LB056+camaro*1.5.csv                                    0.50886
# LB055_LB056+full_candidates.csv                              0.596012
# LB056.csv                                                    0.565287
# LB056_LB055+bugfixed.csv                                     0.552166
# LB057_LB056+safe_candidates.csv                              0.593104
# LB058_LB056+kyakaap*1.5.csv                                  0.586799
# LB058_exp084+full_kyakaap.csv                                0.528873
# LB059+kf0527.csv                                             0.533444
# LB063_camaro_only.csv                                        0.451753
# LB085_LB063+camaro_predictions.csv                                  0

# %%
df
# Out:
#              image_id                                              InChI
# 0        00000d2a601c  InChI=1S/C10H14BrN5S/c1-6-10(11)9(16(3)14-6)4-...
# 1        00001f7fc849  InChI=1S/C14H18ClN3/c1-2-7-16-9-13-10-17-14(18...
# 2        000037687605  InChI=1S/C16H13BrN2O/c1-11(20)12-6-7-13(9-18)1...
# 3        00004b6d55b6  InChI=1S/C14H19FN4O/c1-14(2,3)12-13(16)17-18-1...
# 4        00004df0fe53  InChI=1S/C9H12O2/c1-4-5-2-6-7(3-5)11-9(10)8(4)...
# ...               ...                                                ...
# 1616102  ffffcdb2e39e  InChI=1S/C21H28N2O2/c1-15(2)14-25-19-10-8-17(9...
# 1616103  ffffcfddd770  InChI=1S/C24H28N2O5/c1-5-30-19-9-8-17(13-16(19...
# 1616104  ffffe4ab06b2  InChI=1S/C17H17NO3/c19-12-6-7-14-13(10-12)16-1...
# 1616105  ffffec4033ec  InChI=1S/C12H14F3NO3S/c1-2-3-4-9-16-20(17,18)1...
# 1616106  fffffbebd4f5  InChI=1S/C19H28F3NO3/c1-3-13-26-17-15(7-5-8-16...
#
# [1616107 rows x 2 columns]

# %%
merged_df = pd.concat(submissions, ignore_index=True)

# %%
lb056_df = merged_df.query("filename == 'LB056.csv'")

# %%
df
# Out:
#              image_id                                              InChI
# 0        00000d2a601c  InChI=1S/C10H14BrN5S/c1-6-10(11)9(16(3)14-6)4-...
# 1        00001f7fc849  InChI=1S/C14H18ClN3/c1-2-7-16-9-13-10-17-14(18...
# 2        000037687605  InChI=1S/C16H13BrN2O/c1-11(20)12-6-7-13(9-18)1...
# 3        00004b6d55b6  InChI=1S/C14H19FN4O/c1-14(2,3)12-13(16)17-18-1...
# 4        00004df0fe53  InChI=1S/C9H12O2/c1-4-5-2-6-7(3-5)11-9(10)8(4)...
# ...               ...                                                ...
# 1616102  ffffcdb2e39e  InChI=1S/C21H28N2O2/c1-15(2)14-25-19-10-8-17(9...
# 1616103  ffffcfddd770  InChI=1S/C24H28N2O5/c1-5-30-19-9-8-17(13-16(19...
# 1616104  ffffe4ab06b2  InChI=1S/C17H17NO3/c19-12-6-7-14-13(10-12)16-1...
# 1616105  ffffec4033ec  InChI=1S/C12H14F3NO3S/c1-2-3-4-9-16-20(17,18)1...
# 1616106  fffffbebd4f5  InChI=1S/C19H28F3NO3/c1-3-13-26-17-15(7-5-8-16...
#
# [1616107 rows x 2 columns]

# %%
len(lb056_df.InChI.values != df.InChI.values)
(lb056_df.InChI.values != df.InChI.values).sum()
# Out:
# 0
